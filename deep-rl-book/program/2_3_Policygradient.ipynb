# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 初期の方策を決定するパラメータtheta_0を設定

# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータthetaを行動方策piにソフトマックス関数で変換する手法の定義


def softmax_convert_into_pi_from_theta(theta):
    '''ソフトマックス関数で割合を計算する'''

    beta = 1.0
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # thetaをexp(theta)へと変換

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # simpleに割合の計算の場合

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmaxで計算の場合

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# %%
# 初期の方策pi_0を求める
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 行動aと1step移動後の状態sを求める関数を定義


def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    # pi[s,:]の確率に従って、directionが選択される
    next_direction = np.random.choice(direction, p=pi[s, :])

    if next_direction == "up":
        action = 0
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return [action, s_next]

# %%
# 迷路を解く関数の定義、状態と行動の履歴を出力


def goal_maze_ret_s_a(pi):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 現在の状態（つまり一番最後なのでindex=-1）の行動を代入

        s_a_history.append([next_s, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        if next_s == 8:  # ゴール地点なら終了
            break
        else:
            s = next_s

    return s_a_history

# %%
# 初期の方策で迷路を解く
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
# Out:
# [[0, 1], [1, 3], [0, 2], [3, 1], [4, 3], [3, 1], [4, 3], [3, 1], [4, 2], [7, 1], [8, nan]]
# 迷路を解くのにかかったステップ数は10です

# %%
# thetaの更新関数を定義します


def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 学習率
    T = len(s_a_history) - 1  # ゴールまでの総ステップ数

    [m, n] = theta.shape  # thetaの行列サイズを取得
    delta_theta = theta.copy()  # Δthetaの元を作成、ポインタ参照なので、delta_theta = thetaはダメ

    # delta_thetaを要素ごとに求めます
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])):  # thetaがnanでない場合

                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 履歴から状態iのものを取り出すリスト内包表記です

                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 状態iで行動jをしたものを取り出す

                N_i = len(SA_i)  # 状態iで行動した総回数
                N_ij = len(SA_ij)  # 状態iで行動jをとった回数
                
                # 初版では符号の正負に間違いがありました（修正日：180703）
                #delta_theta[i, j] = (N_ij + pi[i, j] * N_i) / T
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T

    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 方策の更新
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.    0.494 0.506 0.   ]
#  [0.    0.5   0.    0.5  ]
#  [0.    0.    0.5   0.5  ]
#  [0.331 0.339 0.331 0.   ]
#  [0.    0.    0.506 0.494]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.494 0.506 0.    0.   ]]

# %%
# 方策勾配法で迷路を解く

# 初版で、def update_thetaに間違いがあった関係で、終了条件を変更します（修正日：180703）
#stop_epsilon = 10**-8  # 10^-8よりも方策に変化が少なくなったら学習終了とする
stop_epsilon = 10**-4  # 10^-4よりも方策に変化が少なくなったら学習終了とする


theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:  # is_continueがFalseになるまで繰り返す
    s_a_history = goal_maze_ret_s_a(pi)  # 方策πで迷路内を探索した履歴を求める
    new_theta = update_theta(theta, pi, s_a_history)  # パラメータΘを更新
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 方策πの更新

    print(np.sum(np.abs(new_pi - pi)))  # 方策の変化を出力
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
# Out:
# 87
# 迷路を解くのにかかったステップ数は4です
# 0.0001264760899619341
# 迷路を解くのにかかったステップ数は4です
# 0.00012625269712194034
# 迷路を解くのにかかったステップ数は4です
# 0.00012602990484178803
# 迷路を解くのにかかったステップ数は4です
# 0.0001258077109482173
# 迷路を解くのにかかったステップ数は4です
# 0.00012558611327735843
# 迷路を解くのにかかったステップ数は4です
# 0.00012536510967552962
# 迷路を解くのにかかったステップ数は4です
# 0.00012514469799862135
# 迷路を解くのにかかったステップ数は4です
# 0.00012492487611237904
# 迷路を解くのにかかったステップ数は4です
# 0.0001247056418920596
# 迷路を解くのにかかったステップ数は4です
# 0.00012448699322283735
# 迷路を解くのにかかったステップ数は4です
# 0.00012426892799899739
# 迷路を解くのにかかったステップ数は4です
# 0.00012405144412470231
# 迷路を解くのにかかったステップ数は4です
# 0.00012383453951395756
# 迷路を解くのにかかったステップ数は4です
# 0.0001236182120893381
# 迷路を解くのにかかったステップ数は4です
# 0.0001234024597825071
# 迷路を解くのにかかったステップ数は4です
# 0.00012318728053664282
# 迷路を解くのにかかったステップ数は4です
# 0.0001229726723012605
# 迷路を解くのにかかったステップ数は4です
# 0.000122758633037498
# 迷路を解くのにかかったステップ数は4です
# 0.0001225451607144573
# 迷路を解くのにかかったステップ数は4です
# 0.00012233225330962084
# 迷路を解くのにかかったステップ数は4です
# 0.00012211990881173806
# 迷路を解くのにかかったステップ数は4です
# 0.00012190812521665345
# 迷路を解くのにかかったステップ数は4です
# 0.0001216969005301393
# 迷路を解くのにかかったステップ数は4です
# 0.00012148623276616276
# 迷路を解くのにかかったステップ数は4です
# 0.00012127611994839325
# 迷路を解くのにかかったステップ数は4です
# 0.00012106656010909232
# 迷路を解くのにかかったステップ数は4です
# 0.00012085755128861918
# 迷路を解くのにかかったステップ数は4です
# 0.00012064909153674218
# 迷路を解くのにかかったステップ数は4です
# 0.00012044117891138982
# 迷路を解くのにかかったステップ数は4です
# 0.00012023381148061271
# 迷路を解くのにかかったステップ数は4です
# 0.000110054743587348
# 迷路を解くのにかかったステップ数は4です
# 0.00010987137276695716
# 迷路を解くのにかかったステップ数は4です
# 0.00010968847132967335
# 迷路を解くのにかかったステップ数は4です
# 0.001312752648847046
# 迷路を解くのにかかったステップ数は6です
# 0.00011196972299659658
# 迷路を解くのにかかったステップ数は4です
# 0.00011178051118201048
# 迷路を解くのにかかったステップ数は4です
# 0.0001115917919693038
# 迷路を解くのにかかったステップ数は4です
# 0.00011140356361273064
# 迷路を解くのにかかったステップ数は4です
# 0.00011121582437490819
# 迷路を解くのにかかったステップ数は4です
# 0.0013012100767826346
# 迷路を解くのにかかったステップ数は6です
# 0.00011346484758339125
# 迷路を解くのにかかったステップ数は4です
# 0.0001132708282584674
# 迷路を解くのにかかったステップ数は4です
# 0.00011307732139100718
# 迷路を解くのにかかったステップ数は4です
# 0.0010355842099234892
# 迷路を解くのにかかったステップ数は6です
# 0.00011404084905921458
# 迷路を解くのにかかったステップ数は4です
# 0.00011384601635849867
# 迷路を解くのにかかったステップ数は4です
# 0.00011365169675627874
# 迷路を解くのにかかったステップ数は4です
# 0.0001134578884121936
# 迷路を解くのにかかったステップ数は4です
# 0.0001132645894957613
# 迷路を解くのにかかったステップ数は4です
# 0.000113071798184523
# 迷路を解くのにかかったステップ数は4です
# 0.00011287951266311658
# 迷路を解くのにかかったステップ数は4です
# 0.00011268773112626217
# 迷路を解くのにかかったステップ数は4です
# 0.00011249645177595705
# 迷路を解くのにかかったステップ数は4です
# 0.00011230567282195965
# 迷路を解くのにかかったステップ数は4です
# 0.00011211539248236202
# 迷路を解くのにかかったステップ数は4です
# 0.0001119256089844433
# 迷路を解くのにかかったステップ数は4です
# 0.00011173632056162182
# 迷路を解くのにかかったステップ数は4です
# 0.0001115475254560884
# 迷路を解くのにかかったステップ数は4です
# 0.00011135922191862768
# 迷路を解くのにかかったステップ数は4です
# 0.00011117140820697882
# 迷路を解くのにかかったステップ数は4です
# 0.00011098408258701335
# 迷路を解くのにかかったステップ数は4です
# 0.00011079724333324693
# 迷路を解くのにかかったステップ数は4です
# 0.0001106108887253248
# 迷路を解くのにかかったステップ数は4です
# 0.00011042501705395107
# 迷路を解くのにかかったステップ数は4です
# 0.00011023962661553359
# 迷路を解くのにかかったステップ数は4です
# 0.00011005471571430211
# 迷路を解くのにかかったステップ数は4です
# 0.00010987028266251468
# 迷路を解くのにかかったステップ数は4です
# 0.000109686325779592
# 迷路を解くのにかかったステップ数は4です
# 0.00010950284339252339
# 迷路を解くのにかかったステップ数は4です
# 0.00010931983383566206
# 迷路を解くのにかかったステップ数は4です
# 0.0001091372954515335
# 迷路を解くのにかかったステップ数は4です
# 0.00010895522658865495
# 迷路を解くのにかかったステップ数は4です
# 0.00010877362560458154
# 迷路を解くのにかかったステップ数は4です
# 0.00010859249086238483
# 迷路を解くのにかかったステップ数は4です
# 0.00010841182073384296
# 迷路を解くのにかかったステップ数は4です
# 0.00010823161359685592
# 迷路を解くのにかかったステップ数は4です
# 0.00010805186783770931
# 迷路を解くのにかかったステップ数は4です
# 0.00010787258184856256
# 迷路を解くのにかかったステップ数は4です
# 0.00010769375402921826
# 迷路を解くのにかかったステップ数は4です
# 0.00010751538278760443
# 迷路を解くのにかかったステップ数は4です
# 0.0001073374665361438
# 迷路を解くのにかかったステップ数は4です
# 0.00010716000369673413
# 迷路を解くのにかかったステップ数は4です
# 0.0058515828579343825
# 迷路を解くのにかかったステップ数は6です
# 0.00010756377323955374
# 迷路を解くのにかかったステップ数は4です
# 0.00010738644090703582
# 迷路を解くのにかかったステップ数は4です
# 0.0001072095584387471
# 迷路を解くのにかかったステップ数は4です
# 0.00010703312428155844
# 迷路を解くのにかかったステップ数は4です
# 0.00010685713688962997
# 迷路を解くのにかかったステップ数は4です
# 0.00010668159472407811
# 迷路を解くのにかかったステップ数は4です
# 0.00010650649625313854
# 迷路を解くのにかかったステップ数は4です
# 0.00010633183995105606
# 迷路を解くのにかかったステップ数は4です
# 0.0001061576242985373
# 迷路を解くのにかかったステップ数は4です
# 0.0001059838477841038
# 迷路を解くのにかかったステップ数は4です
# 0.00010581050890146396
# 迷路を解くのにかかったステップ数は4です
# 0.00010563760615215495
# 迷路を解くのにかかったステップ数は4です
# 0.00010546513804320437
# 迷路を解くのにかかったステップ数は4です
# 0.00010529310308864288
# 迷路を解くのにかかったステップ数は4です
# 0.00010512149980878953
# 迷路を解くのにかかったステップ数は4です
# 0.00010495032673041652
# 迷路を解くのにかかったステップ数は4です
# 0.00010477958238643524
# 迷路を解くのにかかったステップ数は4です
# 0.00010460926531706723
# 迷路を解くのにかかったステップ数は4です
# 0.00010443937406716397
# 迷路を解くのにかかったステップ数は4です
# 0.00010426990718965037
# 迷路を解くのにかかったステップ数は4です
# 0.00010410086324252367
# 迷路を解くのにかかったステップ数は4です
# 0.00010393224079040773
# 迷路を解くのにかかったステップ数は4です
# 0.00010376403840366664
# 迷路を解くのにかかったステップ数は4です
# 0.0010142770448632512
# 迷路を解くのにかかったステップ数は6です
# 0.00010474984715786069
# 迷路を解くのにかかったステップ数は4です
# 0.00010458012901845386
# 迷路を解くのにかかったステップ数は4です
# 0.00010441083296741302
# 迷路を解くのにかかったステップ数は4です
# 0.00010424195757975478
# 迷路を解くのにかかったステップ数は4です
# 0.00010407350143570686
# 迷路を解くのにかかったステップ数は4です
# 0.00010390546312259372
# 迷路を解くのにかかったステップ数は4です
# 0.00010373784123288848
# 迷路を解くのにかかったステップ数は4です
# 0.0001035706343660639
# 迷路を解くのにかかったステップ数は4です
# 0.0010325617534033358
# 迷路を解くのにかかったステップ数は6です
# 0.00010471937066817288
# 迷路を解くのにかかったステップ数は4です
# 0.0001045501176745716
# 迷路を解くのにかかったステップ数は4です
# 0.00010438128382630682
# 迷路を解くのにかかったステップ数は4です
# 0.00010421286771612227
# 迷路を解くのにかかったステップ数は4です
# 0.00010404486794347509
# 迷路を解くのにかかったステップ数は4です
# 0.0001038772831129433
# 迷路を解くのにかかったステップ数は4です
# 0.00010371011183515216
# 迷路を解くのにかかったステップ数は4です
# 0.001238067942512083
# 迷路を解くのにかかったステップ数は6です
# 0.00010573045519175588
# 迷路を解くのにかかったステップ数は4です
# 0.0001055579482234243
# 迷路を解くのにかかったステップ数は4です
# 0.00010538587357904888
# 迷路を解くのにかかったステップ数は4です
# 0.00010521422978766563
# 迷路を解くのにかかったステップ数は4です
# 0.00010504301538301168
# 迷路を解くのにかかったステップ数は4です
# 0.001029110688587057
# 迷路を解くのにかかったステップ数は6です
# 0.00010606575617042382
# 迷路を解くのにかかったステップ数は4です
# 0.00010589291698257126
# 迷路を解くのにかかったステップ数は4です
# 0.00010572050957636213
# 迷路を解くのにかかったステップ数は4です
# 0.00010554853249106384
# 迷路を解くのにかかったステップ数は4です
# 0.00010537698426860663
# 迷路を解くのにかかったステップ数は4です
# 0.00010520586346026914
# 迷路を解くのにかかったステップ数は4です
# 0.00010503516862085671
# 迷路を解くのにかかったステップ数は4です
# 0.00010486489831394719
# 迷路を解くのにかかったステップ数は4です
# 0.00010469505110728347
# 迷路を解くのにかかったステップ数は4です
# 0.00010452562557581625
# 迷路を解くのにかかったステップ数は4です
# 0.00010435662030019999
# 迷路を解くのにかかったステップ数は4です
# 0.00010418803386592901
# 迷路を解くのにかかったステップ数は4です
# 0.0001040198648682572
# 迷路を解くのにかかったステップ数は4です
# 0.0001038521119031792
# 迷路を解くのにかかったステップ数は4です
# 0.00010368477357717426
# 迷路を解くのにかかったステップ数は4です
# 0.0001035178485000697
# 迷路を解くのにかかったステップ数は4です
# 0.0010416398646062464
# 迷路を解くのにかかったステップ数は6です
# 0.0001046944731001205
# 迷路を解くのにかかったステップ数は4です
# 0.00010452540590292353
# 迷路を解くのにかかったステップ数は4です
# 0.00010435675647803809
# 迷路を解くのにかかったステップ数は4です
# 0.00010418852342726145
# 迷路を解くのにかかったステップ数は4です
# 0.0001040207053593957
# 迷路を解くのにかかったステップ数は4です
# 0.0001038533008893023
# 迷路を解くのにかかったステップ数は4です
# 0.000103686308635784
# 迷路を解くのにかかったステップ数は4です
# 0.00010351972722654271
# 迷路を解くのにかかったステップ数は4です
# 0.00010335355529269598
# 迷路を解くのにかかったステップ数は4です
# 0.00010318779147163587
# 迷路を解くのにかかったステップ数は4です
# 0.00010302243440743486
# 迷路を解くのにかかったステップ数は4です
# 0.00010285748274860632
# 迷路を解くのにかかったステップ数は4です
# 0.00010269293515008382
# 迷路を解くのにかかったステップ数は4です
# 0.00010252879027197737
# 迷路を解くのにかかったステップ数は4です
# 0.00010236504678029675
# 迷路を解くのにかかったステップ数は4です
# 0.00010220170334710246
# 迷路を解くのにかかったステップ数は4です
# 0.00010203875864893755
# 迷路を解くのにかかったステップ数は4です
# 0.00010187621136844606
# 迷路を解くのにかかったステップ数は4です
# 0.00010171406019433317
# 迷路を解くのにかかったステップ数は4です
# 0.00010155230382035384
# 迷路を解くのにかかったステップ数は4です
# 0.00010139094094383481
# 迷路を解くのにかかったステップ数は4です
# 0.00010122997027169761
# 迷路を解くのにかかったステップ数は4です
# 0.00010106939051210753
# 迷路を解くのにかかったステップ数は4です
# 0.00010090920038075858
# 迷路を解くのにかかったステップ数は4です
# 0.0001007493985987519
# 迷路を解くのにかかったステップ数は4です
# 0.00010058998389145778
# 迷路を解くのにかかったステップ数は4です
# 0.00010043095499019661
# 迷路を解くのにかかったステップ数は4です
# 0.00010027231063089795
# 迷路を解くのにかかったステップ数は4です
# 0.00010011404955643892
# 迷路を解くのにかかったステップ数は4です
# 9.995617051222934e-05
# 迷路を解くのにかかったステップ数は4です

# %%
# 最終的な方策を確認
np.set_printoptions(precision=3, suppress=True)  # 有効桁数3、指数表示しないという設定
print(pi)
# Out:
# [[0.    0.01  0.99  0.   ]
#  [0.    0.339 0.    0.661]
#  [0.    0.    0.441 0.559]
#  [0.012 0.975 0.013 0.   ]
#  [0.    0.    0.986 0.014]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.015 0.985 0.    0.   ]]

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 3) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 2.5 - int(state / 3)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfbbd02fd95e04a2a801e170efdd8a7ce">
#   <div class="anim-controls">
#     <input id="_anim_sliderfbbd02fd95e04a2a801e170efdd8a7ce" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfbbd02fd95e04a2a801e170efdd8a7ce.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animfbbd02fd95e04a2a801e170efdd8a7ce.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectfbbd02fd95e04a2a801e170efdd8a7ce"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fbbd02fd95e04a2a801e170efdd8a7ce"
#              checked>
#       <label for="_anim_radio1_fbbd02fd95e04a2a801e170efdd8a7ce">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fbbd02fd95e04a2a801e170efdd8a7ce"
#              >
#       <label for="_anim_radio2_fbbd02fd95e04a2a801e170efdd8a7ce">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fbbd02fd95e04a2a801e170efdd8a7ce"
#              >
#       <label for="_anim_radio3_fbbd02fd95e04a2a801e170efdd8a7ce">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfbbd02fd95e04a2a801e170efdd8a7ce";
#     var slider_id = "_anim_sliderfbbd02fd95e04a2a801e170efdd8a7ce";
#     var loop_select_id = "_anim_loop_selectfbbd02fd95e04a2a801e170efdd8a7ce";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/Il7ecAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAmfUlEQVR4nO3de3RV5Z3/8fc3N26Bwk+oQpCLg0pDS9VEBrTjheiIdihtEX9C\
# qwIWvFDrVFxUZ6xW+3OWUtGlhVGzClgv4/1SYNQahWIRKw2KKEgt0yoSaAmRixCSEPL9/XFOmBAT\
# kmB29nOSz2utszzn7Ccnnzyln+w8Z+99zN0REZHwpMUdQEREGqaCFhEJlApaRCRQKmgRkUCpoEVE\
# AqWCFhEJlApaRCRQKmgRkUCpoEVEAqW
